# %%
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/My Drive/Colab Notebooks/craud/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Пары подряд идущих запросов пользователей из таблицы пользовательских сессий:

# %%
data = pd.read_csv(path + 'query.csv')
data
# Out:
#                                       id  ...                                             query2
# 0        y1000000361630744646-1631522512  ...                           Автобус саранск тольятти
# 1        y1000000361630744646-1631522512  ...                                                tit
# 2        y1000000361630744646-1631522512  ...                                 Метро москвы схема
# 3        y1000000361630744646-1631522512  ...              санино киевская расписание электричек
# 4        y1000000361630744646-1631522512  ...                                       голден палас
# ...                                  ...  ...                                                ...
# 1475271  y9999969291608062519-1632251234  ...                               декоративная подушка
# 1475272  y9999969291608062519-1632251234  ...                                  картины модульные
# 1475273  y9999969291608062519-1632251234  ...                         русские горки о чем сериал
# 1475274  y9999969291608062519-1632251234  ...                                          сима ленд
# 1475275  y9999969291608062519-1632251234  ...  как правильно развесить настенный декор в инте...
#
# [1475276 rows x 3 columns]

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.46)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.3.0)
# Requirement already satisfied: huggingface-hub>=0.0.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.19)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.17->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)

# %%
# !pip install pytorch_lightning
# Out:
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.7/dist-packages (1.4.9)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (1.9.0+cu111)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (1.19.5)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (4.62.3)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (2021.10.1)
# Requirement already satisfied: torchmetrics>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (0.5.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (21.0)
# Requirement already satisfied: pyDeprecate==0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (0.3.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (3.7.4.3)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (0.18.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (2.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.7.4.post0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.23.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch_lightning) (2.4.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.3.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.12.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.17.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.41.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.37.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (57.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch_lightning) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (3.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.7.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (21.2.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (3.6.0)

# %%
import argparse
from typing import Dict
import os
import json
import random

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, RandomSampler

from transformers import AutoModel, AutoTokenizer, AdamW

from pytorch_lightning import LightningModule, Trainer
from pytorch_lightning.callbacks import EarlyStopping

os.environ["TOKENIZERS_PARALLELISM"] = "0"

class Embedder(nn.Module):
    def __init__(self, model_path, freeze_bert, layer_num):
        super().__init__()

        self.model = AutoModel.from_pretrained(model_path)
        self.model.trainable = not freeze_bert
        self.bert_dim = self.model.config.hidden_size
        self.layer_num = layer_num

    def forward(self, input_ids, attention_mask):
        output = self.model(
           input_ids,
           attention_mask=attention_mask,
           return_dict=True,
           output_hidden_states=True
        )
        layer_embeddings = output.hidden_states[self.layer_num]
        embeddings = torch.mean(layer_embeddings, dim=1)
        norm = embeddings.norm(p=2, dim=1, keepdim=True)
        embeddings = embeddings.div(norm)
        return embeddings


class ClusteringContrastiveModel(LightningModule):
    def __init__(self, model_path, freeze_bert=False, layer_num=-1, margin=0.5, lr=1e-5):
        super().__init__()

        self.embedder = Embedder(
            model_path,
            freeze_bert=freeze_bert,
            layer_num=layer_num
        )
        self.lr = lr
        self.loss = nn.CosineEmbeddingLoss(margin=margin)

    def forward(self, left, right, labels):
        left_embeddings = self.embedder(left["input_ids"], left["attention_mask"])
        right_embeddings = self.embedder(right["input_ids"], right["attention_mask"])
        loss = self.loss(left_embeddings, right_embeddings, labels)
        return loss

    def training_step(self, batch, batch_nb):
        train_loss = self(*batch)
        return train_loss

    def validation_step(self, batch, batch_nb):
        val_loss = self(*batch)
        self.log("val_loss", val_loss, prog_bar=True, logger=True)
        return val_loss

    def configure_optimizers(self):
        optimizer = AdamW(self.parameters(), lr=self.lr)
        return [optimizer]



class NewsDataset(Dataset):
    def __init__(self, records, model_path, max_tokens):
        self.tokenizer = AutoTokenizer.from_pretrained(
            model_path
        )
        self.max_tokens = max_tokens
        self.records = records

    def __len__(self):
        return len(self.records)

    def __getitem__(self, index):
        fields = self.records[index]
        label = fields[-1]
        samples = fields[:-1]
        samples = [self.tokenizer(
            s,
            add_special_tokens=True,
            max_length=self.max_tokens,
            padding="max_length",
            truncation=True,
            return_tensors='pt'
        ) for s in samples]
        samples = [{key: value.squeeze(0) for key, value in s.items()} for s in samples]
        return samples[0], samples[1], torch.tensor(float(1 if label == 1 else -1))


def form_pairs(filename):
    records = []
    with open(filename, "r") as f:
        for line in f:
            record = json.loads(line)
            records.append((record["s1"], record["s2"], record["target"]))
    return records


def train_paraphrases(
    initial_model_name,
    train_path,
    max_tokens,
    out_dir,
    batch_size,
    grad_accum_steps,
    epochs,
    lr
):
    records = form_pairs(train_path)
    random.shuffle(records)
    border = int(len(records) * 0.8)
    train_records = records[:border]
    val_records = records[border:]

    train_data = NewsDataset(train_records, initial_model_name, max_tokens)
    train_sampler = RandomSampler(train_data)
    train_loader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

    val_data = NewsDataset(val_records, initial_model_name, max_tokens)
    val_loader = DataLoader(val_data, batch_size=batch_size)

    LOG_EVERY_N_STEPS = 5
    model = ClusteringContrastiveModel(initial_model_name, lr=lr)
    early_stop_callback = EarlyStopping(
        monitor="val_loss",
        min_delta=0.0001,
        patience=3,
        verbose=True,
        mode="min"
    )
    trainer = Trainer(
        gpus=1,
        checkpoint_callback=True,
        accumulate_grad_batches=grad_accum_steps,
        max_epochs=epochs,
        callbacks=[early_stop_callback],
        log_every_n_steps=LOG_EVERY_N_STEPS
    )
    trainer.fit(model, train_loader, val_loader)
    train_data.tokenizer.save_pretrained(out_dir)
    model.embedder.model.save_pretrained(out_dir)

# %% [markdown]
# Загрузим данные, размеченные в Толоке:

# %%
pool1 = pd.read_csv(path + 'result1.tsv', sep='\t')
pool2 = pd.read_csv(path + 'result2.tsv', sep='\t')

# %%
df = pd.concat([pool1, pool2])

# %%
df
# Out:
#                      INPUT:session_id  ... Unnamed: 5
# 0     y5491971611630764813-1631723433  ...        NaN
# 1     y4536280011629492713-1630602486  ...        NaN
# 2     y3158831181592565381-1632230634  ...        NaN
# 3     y6962060371631071364-1631191948  ...        NaN
# 4     y4645798721619525366-1631695151  ...        NaN
# ...                               ...  ...        ...
# 9985  y5378697651579646182-1631634228  ...        NaN
# 9986  y7057059081618518771-1632331397  ...        NaN
# 9987  y5593890401604246131-1631555898  ...        NaN
# 9988  y5004841251605798003-1632144248  ...        NaN
# 9989  y8416690551014320381-1631653239  ...        NaN
#
# [19987 rows x 6 columns]

# %%
train = df.copy()
train.drop(columns=["INPUT:session_id", "CONFIDENCE:res", "Unnamed: 5"], inplace=True)
train.rename(columns = {'INPUT:text1':'s1', 'INPUT:text2':'s2', 'OUTPUT:res':'target'}, inplace = True)
train
# Out:
#                                                      s1  ... target
# 0     беседы по социальному окружению "кто нас воспи...  ...      1
# 1                      коснулся разбор слова по составу  ...      0
# 2                 русь санаторий анапа официальный сайт  ...      1
# 3     государство 9 класс обществознание конспект урока  ...      0
# 4                               мид и вклад в социологю  ...      0
# ...                                                 ...  ...    ...
# 9985       электронной дневник московской области школа  ...      0
# 9986                  переливает бензин рено сафран 2.0  ...      1
# 9987  как правильно сделать договор аренды трактора ...  ...      1
# 9988                            нужна финансовая помощь  ...      1
# 9989                 мрз узбекча скачать бесплатно 2021  ...      0
#
# [19987 rows x 3 columns]

# %%
train.to_csv(path + 'train.csv')

# %%
# сохраним в train файл с jsonами
import json
train.to_json(path+'train.json', orient='records', lines=True)

# %%
records = []
with open(path+'train.json', "r") as f:
  for line in f:
    record = json.loads(line)
    records.append((record["s1"], record["s2"], record["target"]))

# %% [markdown]
# # Обучение на всей разметке из Толоки и предсказание схожести для части неразмеченных пар запросов

# %% [markdown]
# Вначале обучим модель на всем размеченном датасете:

# %%
# if __name__ == "__main__":
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--initial-model-name", type=str, default="DeepPavlov/rubert-base-cased")
#     parser.add_argument("--train-path", type=str, required=True)
#     parser.add_argument("--max-tokens", type=int, default=64)
#     parser.add_argument("--out-dir", type=str, required=True)
#     parser.add_argument("--batch-size", type=int, default=32)
#     parser.add_argument("--grad-accum-steps", type=int, default=8)
#     parser.add_argument("--epochs", type=int, default=5)
#     parser.add_argument("--lr", type=float, default=1e-05)
#     args = parser.parse_args()
#     train_paraphrases(**vars(args))


train_paraphrases(initial_model_name="DeepPavlov/rubert-base-cased",
                  train_path=path+'train.json',
                  max_tokens=64,
                  out_dir=path+'train_all/',
                  batch_size=32,
                  grad_accum_steps=8,
                  epochs=5,
                  lr=1e-05)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type                | Params
# -------------------------------------------------
# 0 | embedder | Embedder            | 177 M
# 1 | loss     | CosineEmbeddingLoss | 0
# -------------------------------------------------
# 177 M     Trainable params
# 0         Non-trainable params
# 177 M     Total params
# 711.414   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Metric val_loss improved. New best score: 0.095
# Validating: 0it [00:00, ?it/s]
# Metric val_loss improved by 0.007 >= min_delta = 0.0001. New best score: 0.088
# Validating: 0it [00:00, ?it/s]
# Metric val_loss improved by 0.002 >= min_delta = 0.0001. New best score: 0.086
# Validating: 0it [00:00, ?it/s]
# Metric val_loss improved by 0.001 >= min_delta = 0.0001. New best score: 0.085
# Validating: 0it [00:00, ?it/s]
# Metric val_loss improved by 0.000 >= min_delta = 0.0001. New best score: 0.085

# %% [markdown]
# Лучший скор на валидационной выборке получился: **0.085**

# %%
model
# Out:
# ClusteringContrastiveModel(
#   (embedder): Embedder(
#     (model): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(119547, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (activation): Tanh()
#       )
#     )
#   )
#   (loss): CosineEmbeddingLoss()
# )

# %% [markdown]
# Теперь с ее помощью можно предсказать схожесть подряд идущих запросов из таблицы сессий:

# %%
test_all = data.copy()
test_all.drop(columns=["id"], inplace=True)
test_all.rename(columns = {'query1':'s1', 'query2':'s2'}, inplace = True)
test_all.to_json(path+'test_all.json', orient='records', lines=True)

# %% [markdown]
# Загрузим обученную модель:

# %%
model_path = path + 'train_all/'
model = ClusteringContrastiveModel(model_path)

# %%
records_test = []
with open(path+'test_all.json', "r") as f:
  for line in f:
    record = json.loads(line)
    record["target"] = 0
    if record["s1"] != None and record["s2"] != None:
      records_test.append((record["s1"], record["s2"], record["target"] ))

# %%
len(records_test)
# Out:
# 1474377

# %% [markdown]
# Поскольку датасет очень большой и содержит порядка **~1.4** миллиона пар, обработаем хотя бы **30000** из них:

# %%
records_small = records_test[:30000]

# %%
news_dataset = NewsDataset(records_small, model_path, 64)
test_loader = DataLoader(news_dataset, batch_size=1)

# %%
res = []
prediction_list = []
for i, (l, r, t) in enumerate(test_loader):
  output = model(l, r, t)
  res.append((i, records_test[i][0], records_test[i][1], output.item()))
  prediction_list.append(output.item())

# %%
res_df = pd.DataFrame(res, columns =['index', 's1', 's2', 'prob'])
res_df
# Out:
#        index  ...      prob
# 0          0  ...  0.000000
# 1          1  ...  0.000000
# 2          2  ...  0.084691
# 3          3  ...  0.000000
# 4          4  ...  0.000000
# ...      ...  ...       ...
# 29995  29995  ...  0.494550
# 29996  29996  ...  0.468876
# 29997  29997  ...  0.000000
# 29998  29998  ...  0.381625
# 29999  29999  ...  0.468876
#
# [30000 rows x 4 columns]

# %%
res_df.to_csv(path+'res_probs_30000.csv')
# Out:
#    Unnamed: 0  index  ...                                       s2      prob
# 0           0  25001  ...  продажа квартиры по Алабяна д 10 корп 3  0.179163
# 1           1  25002  ...         что это за здание алабяна 15 с 2  0.498699
# 2           2  25003  ...         что это за здание алабяна 10 с 3  0.498699
# 3           3  25004  ...   дайте оскар этой богине песня кто поет  0.000000
# 4           4  25005  ...                               лана роудс  0.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# # Обучение и тестирование на разметке из Толоки

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(train, test_size=0.15, random_state=42)
train_df.to_json(path+'train_df.json', orient='records', lines=True)
test_df.to_json(path+'test_df.json', orient='records', lines=True)

# %%
train_df[:2000].to_csv(path + 'train_small.csv')

# %%
records = []
with open(path+'train_df.json', "r") as f:
  for line in f:
    record = json.loads(line)
    records.append((record["s1"], record["s2"], record["target"]))

# %%
# if __name__ == "__main__":
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--initial-model-name", type=str, default="DeepPavlov/rubert-base-cased")
#     parser.add_argument("--train-path", type=str, required=True)
#     parser.add_argument("--max-tokens", type=int, default=64)
#     parser.add_argument("--out-dir", type=str, required=True)
#     parser.add_argument("--batch-size", type=int, default=32)
#     parser.add_argument("--grad-accum-steps", type=int, default=8)
#     parser.add_argument("--epochs", type=int, default=5)
#     parser.add_argument("--lr", type=float, default=1e-05)
#     args = parser.parse_args()
#     train_paraphrases(**vars(args))


train_paraphrases(initial_model_name="DeepPavlov/rubert-base-cased",
                  train_path=path+'train_df.json',
                  max_tokens=64,
                  out_dir=path+'train/',
                  batch_size=32,
                  grad_accum_steps=8,
                  epochs=5,
                  lr=1e-05)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type                | Params
# -------------------------------------------------
# 0 | embedder | Embedder            | 177 M
# 1 | loss     | CosineEmbeddingLoss | 0
# -------------------------------------------------
# 177 M     Trainable params
# 0         Non-trainable params
# 177 M     Total params
# 711.414   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Metric val_loss improved. New best score: 0.099
# Validating: 0it [00:00, ?it/s]
# Metric val_loss improved by 0.008 >= min_delta = 0.0001. New best score: 0.091
# Validating: 0it [00:00, ?it/s]
# Metric val_loss improved by 0.002 >= min_delta = 0.0001. New best score: 0.089
# Validating: 0it [00:00, ?it/s]
# Metric val_loss improved by 0.001 >= min_delta = 0.0001. New best score: 0.087
# Validating: 0it [00:00, ?it/s]
# Metric val_loss improved by 0.000 >= min_delta = 0.0001. New best score: 0.087

# %%
model_test = ClusteringContrastiveModel(path + 'train/')

records = []
with open(path+'test_df.json', "r") as f:
  for line in f:
    record = json.loads(line)
    if record["s1"] != None and record["s2"] != None:
      records.append((record["s1"], record["s2"], record["target"] ))

# %%
len(records)
# Out:
# 2999

# %%
news_dataset = NewsDataset(records, path + 'train/', 64)
test_loader = DataLoader(news_dataset, batch_size=1)

preds = []
y_true = []
for i, (l, r, t) in enumerate(test_loader):
  output = model_test(l, r, t)
  preds.append(output.item())
  y_true.append(records[i][2])

# %%
preds_labeled = []
for i in preds:
  if i >= 0.5:
    preds_labeled.append(1)
  else:
    preds_labeled.append(0)

# %%
from sklearn.metrics import mean_absolute_error, f1_score, accuracy_score

print('MAE score: ', mean_absolute_error(y_true, preds_labeled))
# Out:
# MAE score:  0.4551517172390797

# %%
test_dataset = pd.read_csv(path+'test_dataset.csv')

# %%
test_dataset
# Out:
#      Unnamed: 0  ...                                             query2
# 0             0  ...                           как сделать двойную веку
# 1             1  ...       что надо сделать чтобы поднялась температура
# 2             2  ...                             тошнота как избавиться
# 3             3  ...                         как скачать песню на айфон
# 4             4  ...  если мало есть и заниматься спортом можно ли п...
# ..          ...  ...                                                ...
# 495         495  ...                  отучить котенка писать на кровать
# 496         496  ...                      как хранить деньги в кошельке
# 497         497  ...                        жирная кожа лица что делать
# 498         498  ...                       как ломается голос у девочек
# 499         499  ...                                   как выбрать обои
#
# [500 rows x 3 columns]

# %%
records = []
for _, row in test_dataset.iterrows():
    records.append((row["query1"], row["query2"], 0))

# %%
news_dataset = NewsDataset(records, path + 'train/', 64)
test_loader = DataLoader(news_dataset, batch_size=1)

preds = []
for i, (l, r, t) in enumerate(test_loader):
  output = model_test(l, r, t)
  preds.append(output.item())

# %%
res_not_zero = []
res_all = []
for i in range(len(records)):
  print((i, records[i][0], records[i][1], preds[i]))
  res_all.append((i, records[i][0], records[i][1], preds[i]))
  if preds[i] > 0.03:
    res_not_zero.append((i, records[i][0], records[i][1], preds[i]))
# Out:
# (0, 'как царапать глаза', 'как сделать двойную веку', 0.02437150478363037)
# (1, 'основные методы реабилитации пороках сердца', 'что надо сделать чтобы поднялась температура', 0.0)
# (2, 'кетонал инструкция по применению', 'тошнота как избавиться', 0.0)
# (3, 'лобода песня суперзвезда клип', 'как скачать песню на айфон', 0.0)
# (4, 'цинктерал стоимость в аптеке', 'если мало есть и заниматься спортом можно ли похудеть', 0.0)
# (5, 'создать аккаунт гугл', 'создать аккаунт gmail', 0.3481371998786926)
# (6, 'перепелиные яйца польза и вред как принимать', 'как сварить рассыпчатый рис', 0.03172045946121216)
# (7, 'virtualbox debian', 'как создать новый файл в терминале', 0.0)
# (8, 'как правильно приготовить фрикадельки для супа', 'как правильно приготовить суп', 0.40471845865249634)
# (9, 'информация по imei', 'как сбросить настройки айфона', 0.0)
# (10, 'математика', 'учим английский язык с нуля', 0.08509963750839233)
# (11, 'развитие мотивации профессиональной деятельности', 'мотивация', 0.189630389213562)
# (12, 'как узнать что у тебя начались месячные', 'как узнать что у тебя месячные', 0.4413757920265198)
# (13, 'работодатель не выплачивает зарплату после увольнения', 'как правильно уволиться с работы по собственному желанию', 0.2328130006790161)
# (14, 'как откатить систему', 'как восстановить удаленные файлы', 0.18819111585617065)
# (15, 'обрезание у мужчин делают всем?', 'зачем делают обрезание у мужчин мусульман', 0.4570774435997009)
# (16, 'свойства степеней', 'графики функций', 0.0)
# (17, 'стоит ли знакомиться на улице прямым способом?', 'как попасть к девушке домой после свидания', 0.1442365050315857)
# (18, 'iptv настроить на samsung 2013', 'как узнать ip адрес своего провайдера', 0.1898314356803894)
# (19, 'почему нельзя смотреть кошкам в глаза', 'почему нельзя спать напротив зеркала', 0.12384438514709473)
# (20, 'муж называет бесплодной', 'выкидыш из за работы', 0.1563069224357605)
# (21, 'как восстановить работу internet explorer в windows 7', 'не могу найти internet explorer на компьютере', 0.29597240686416626)
# (22, 'какие бывают подводки картинки', 'как выбрать подводку для глаз', 0.29073864221572876)
# (23, 'не работает fn на ноутбуке', 'как включить беспроводную сеть на ноутбуке', 0.1710262894630432)
# (24, 'как быстро похудеть', 'мотивация', 0.0)
# (25, 'как блокировать рекламу в яндекс браузере', 'как блокировать рекламу в гугл хром', 0.46030759811401367)
# (26, 'скачать игру words of wonders', 'как играть в судоку', 0.0)
# (27, 'роды в 30 лет', 'аппендицит', 0.0)
# (28, 'педикулез', 'как избавиться от гнид', 0.0)
# (29, 'диаметр по площади круга', 'площадь круга', 0.3253917098045349)
# (30, 'тесто для вареников с картошкой', 'что делать если тесто плохо раскатывается', 0.35073453187942505)
# (31, 'спортивное питание сибирское здоровье каталог', 'как облегчить боль в мышцах после тренировки', 0.0)
# (32, 'скачать картинки с днем рождения брату', 'как сделать слайд шоу из фотографий с музыкой', 0.0)
# (33, 'кот гадит мимо лотка что делать', 'чем убрать запах кошачьей мочи', 0.0)
# (34, 'жизнь без невроза', 'как перестать беспокоиться и начать жить', 0.11551451683044434)
# (35, 'как сделать маникюр гель лаком в домашних условиях самой себе', 'как накрасить ногти', 0.2798670530319214)
# (36, 'хищники 2018 скачать торрент', 'фильмы которые стоит посмотреть', 0.012908339500427246)
# (37, 'редуксин отзывы', 'как уменьшить аппетит', 0.0)
# (38, 'отработка при увольнении по собственному желанию 2018', 'заявление на увольнение', 0.24625104665756226)
# (39, 'ютуб', 'как сохранить видео с ютуба', 0.062086403369903564)
# (40, 'научиться рисовать карандашом с нуля поэтапно для начинающих', 'хобби', 0.0)
# (41, 'дексаметазон', 'как набрать вес', 0.0)
# (42, 'пепельный цвет волос на шоколадныхволосах', 'цвета волос', 0.3188289999961853)
# (43, 'сладкие сдобные пироги', 'как красиво украсить сдобный пирог', 0.26587557792663574)
# (44, 'борная кислота для рвоты', 'что может остановить рвоту', 0.0)
# (45, 'сыворотка для лица', 'фарфоровая кожа как добиться', 0.10395514965057373)
# (46, 'распирающая боль внизу живота у женщин', 'аппендицит', 0.11706799268722534)
# (47, 'как эффективно похудеть', 'как быстро похудеть', 0.4812825918197632)
# (48, 'как сжать фильм чтобы он меньше весил', 'как сжать фильм для записи на флешку без потери качества', 0.39141982793807983)
# (49, 'как называется жвачка для рук', 'как сделать слайм из шампуня', 0.07714009284973145)
# (50, 'пдд онлайн 2018 экзамен билеты как в гаи', 'как правильно настроить зеркала заднего вида в легковом автомобиле', 0.0)
# (51, 'минимальный наклон крыши для гибкой черепицы', 'расчет угла', 0.06629174947738647)
# (52, 'месть соседям', 'как отомстить соседям сверху за шум', 0.2848416566848755)
# (53, 'супы на курином бульоне рецепты', 'рассольник рецепт', 0.09539586305618286)
# (54, 'где хранятся сохранения gta 5', 'как увидеть скрытые папки', 0.07665103673934937)
# (55, 'прыщ на носу примета', 'прыщ на носу как быстро избавиться', 0.46034812927246094)
# (56, 'как узнать нравлюсь ли я девушке', 'как признаться в любви девушке', 0.2259238362312317)
# (57, 'программы для монтажа видео', 'как научиться монтировать видео', 0.3184770345687866)
# (58, 'отравление от кураги', 'что делать при отравлении', 0.24693375825881958)
# (59, 'квадратные уравнения онлайн', 'площадь треугольника', 0.13088852167129517)
# (60, 'утренняя служба в церкви сколько длится', 'во сколько нужно приходить на исповедь', 0.12904590368270874)
# (61, 'почему и зачем дерутся хомяки если они одного пола', 'клетки для хомяков', 0.16993361711502075)
# (62, 'как не впустить снова человека в свою жизнь', 'как забыть парня', 0.24404919147491455)
# (63, 'длина окружности калькулятор', 'площадь круга', 0.276218056678772)
# (64, 'работа в сбербанке вакансии в москве', 'что писать в резюме о себе', 0.0)
# (65, 'как подобрать стрижку', 'программа как подобрать прическу', 0.36609959602355957)
# (66, 'салат с фасолью на ужин', 'как правильно сварить фасоль чтобы она была мягкой', 0.16631954908370972)
# (67, 'как настроить себя на позитив и на хорошие мысли', 'как мыслить позитивно', 0.23076778650283813)
# (68, 'как получить пособие по безработице в 2018 году', 'как заработать деньги', 0.15997827053070068)
# (69, 'как без вреда осветлить волосы айрекоменд', 'как смыть хну с волос в домашних условиях', 0.28272438049316406)
# (70, 'поделка самокат своими руками из пластилина', 'нарисовать самокат карандашом', 0.3216360807418823)
# (71, 'как отучить взрослого кота писать', 'чем убрать запах кошачьей мочи', 0.06810539960861206)
# (72, 'как дешево питаться', 'как приготовить блины', 0.1884137988090515)
# (73, 'как сварить суп с соленым огурцом', 'как сварить рассольник', 0.3352430462837219)
# (74, 'можно ли похудеть на воде', 'избавление от целлюлита', 0.008200407028198242)
# (75, 'можно ли прослушивать телефон', 'как узнать прослушивают телефон или нет', 0.42432641983032227)
# (76, 'можно кушать вишню перед узи брюшной полости', 'как сделать клизму в домашних условиях самому себе', 0.08163231611251831)
# (77, 'аренда квартир в симферополе', 'аренда квартир в симферополе без посредников', 0.49529075622558594)
# (78, 'биография прокурора украины юрия луценко', 'жена юрия луценко', 0.151059091091156)
# (79, 'вайлдберриз', 'Как правильно покупать в интернет магазинах', 0.0)
# (80, 'вайлдберриз', 'вайлдберриз промокод', 0.4843509793281555)
# (81, 'гепариновая от синяков', 'гематома', 0.0)
# (82, 'гепариновая от синяков', 'гепариновая мазь цена', 0.45091986656188965)
# (83, 'гепариновая от синяков', 'что помогает от синяков', 0.0)
# (84, 'гепариновая от синяков', 'как убрать синяк', 0.0)
# (85, 'группа компаний хамина официальный сайт', 'застройщики воронежа список 2018', 0.02146124839782715)
# (86, 'джум', 'какие проблемы при заказе из китая', 0.0)
# (87, 'джум', 'Самые популярные товары из Китая', 0.0)
# (88, 'джум', 'отслеживание посылки из китая', 0.0)
# (89, 'джум', 'джум или али экспресс', 0.45844149589538574)
# (90, 'дурак смотреть', 'фильмы юрия быкова', 0.028860032558441162)
# (91, 'игрушки из ткани своими руками выкройки мишки', 'игрушки из фетра выкройки распечатать', 0.39922845363616943)
# (92, 'игрушки из ткани своими руками выкройки мишки', 'история мягкой игрушки', 0.27884161472320557)
# (93, 'игрушки из ткани своими руками выкройки мишки', 'мягкие игрушки своими руками из ткани выкройки для начинающих', 0.44595807790756226)
# (94, 'игрушки из ткани своими руками выкройки мишки', 'как сшить мишку тедди своими руками', 0.31132346391677856)
# (95, 'игрушки из ткани своими руками выкройки мишки', 'как выбрать ткань для игрушки', 0.3241368532180786)
# (96, 'игрушки из ткани своими руками выкройки мишки', 'плюшевый мишка', 0.1401950716972351)
# (97, 'игры для мальчиков', 'игры для мальчиков бесплатно', 0.48906612396240234)
# (98, 'игры для мальчиков', 'игры гонки', 0.21508866548538208)
# (99, 'игры для мальчиков', 'игры стрелялки', 0.22707265615463257)
# (100, 'как будет работать зеленоградский цэд', 'новые таможенные технологии', 0.0)
# (101, 'как будет работать зеленоградский цэд', 'московская областная таможня', 0.0)
# (102, 'как будет работать зеленоградский цэд', 'зеленоградский цэд контакты', 0.3505765199661255)
# (103, 'капитолий замороженый егурт', 'тутти фрутти цены', 0.0)
# (104, 'капитолий замороженый егурт', 'замороженный йогурт в москве адреса', 0.0003355741500854492)
# (105, 'капитолий замороженый егурт', 'замороженный йогурт калорийность', 0.0)
# (106, 'капитолий замороженый егурт', 'история замороженного йогурта', 0.0)
# (107, 'капитолий замороженый егурт', 'полезные свойства йогурта', 0.0)
# (108, 'капитолий замороженый егурт', 'замороженный йогурт дома', 0.0)
# (109, 'картинки с днем рождения', 'с днем рождения поздравления', 0.3208823800086975)
# (110, 'картинки с днем рождения', 'с днем рождения видео', 0.3779255747795105)
# (111, 'картинки с днем рождения', 'картинки с днем рождения мужчине', 0.47492581605911255)
# (112, 'картинки с днем рождения', 'как нарисовать открытку', 0.09677338600158691)
# (113, 'картинки с днем рождения', 'картинки с днем рождения женщине', 0.4607420563697815)
# (114, 'картинки с днем рождения', 'факты о дне рождении', 0.2624867558479309)
# (115, 'картинки с днем рождения', 'смешные открытки', 0.09055274724960327)
# (116, 'лихтенштейн', 'что делать в лихтенштейне', 0.25380629301071167)
# (117, 'лихтенштейн', 'где находится лихтенштейн', 0.4569128751754761)
# (118, 'лихтенштейн', 'лихтенштейн достопримечательности', 0.48980510234832764)
# (119, 'любовь с ограничениями фильм 2016', 'любовь с ограничениями фильм 2016 актеры', 0.49810051918029785)
# (120, 'любовь с ограничениями фильм 2016', 'любовь с ограничениями фильм 2016 смотреть онлайн', 0.49621206521987915)
# (121, 'любовь с ограничениями фильм 2016', 'лучшие фильмы о любви', 0.3116694688796997)
# (122, 'любовь с ограничениями фильм 2016', 'любовь с ограничениями фильм 2016 трейлер', 0.49547094106674194)
# (123, 'майкл корс часы официальный сайт', 'где купить оригинальные часы майкл корс в москве', 0.31392019987106323)
# (124, 'майкл корс часы официальный сайт', 'michael kors часы как отличить подделку', 0.1019742488861084)
# (125, 'майкл корс часы официальный сайт', 'самые дорогие часы в мире', 0.11850595474243164)
# (126, 'майкл корс часы официальный сайт', 'сколько стоят часы майкл корс оригинал', 0.3367127776145935)
# (127, 'майкл корс часы официальный сайт', 'биография майкла корса', 0.35249459743499756)
# (128, 'майкл корс часы официальный сайт', 'с чем носят часы', 0.13042747974395752)
# (129, 'майя шхалахова', 'майя шхалахова одноклассники', 0.48757195472717285)
# (130, 'майя шхалахова', 'мая шхалахова', 0.23299497365951538)
# (131, 'майя шхалахова', 'майя шхалахова фото', 0.48823195695877075)
# (132, 'мечеть шейха зейта)', 'как устроена мечеть', 0.19185638427734375)
# (133, 'мечеть шейха зейта)', 'где находится самая большая мечеть в мире', 0.21323299407958984)
# (134, 'мечеть шейха зейта)', 'Исламская архитектура', 0.05277496576309204)
# (135, 'мечеть шейха зейта)', 'мечеть шейха зайда на карте', 0.4585540294647217)
# (136, 'мечеть шейха зейта)', 'мечеть', 0.2783092260360718)
# (137, 'мечеть шейха зейта)', 'что посмотреть в абу-даби', 0.0)
# (138, 'мои награды фанера купить', 'Спортивные награды', 0.259135901927948)
# (139, 'мои награды фанера купить', 'подставка для медалей и кубков', 0.0)
# (140, 'мои награды фанера купить', 'именная медальница купить', 0.163068950176239)
# (141, 'мои награды фанера купить', 'подставка для медалей из фанеры', 0.0)
# (142, 'мос ру', 'найти и оплатить штрафы', 0.0)
# (143, 'мос ру', 'электронный дневник', 0.0)
# (144, 'мос ру', 'внести показания счетчиков на мос ру', 0.0)
# (145, 'мос ру', 'как зарегистрироваться на мос ру', 0.3096013069152832)
# (146, 'не убирается подчеркивание ссылок', 'как убрать подчеркивание текста в ворде при копировании из интернета', 0.2854948043823242)
# (147, 'не убирается подчеркивание ссылок', 'как в css убрать подчеркивание ссылки', 0.12149858474731445)
# (148, 'не убирается подчеркивание ссылок', 'как убрать подчеркивание ссылок в wordpress', 0.3363956809043884)
# (149, 'почта россии сроки доставки посылок по россии', 'почта россии отслеживание', 0.44753414392471313)
# (150, 'почта россии сроки доставки посылок по россии', 'скорость доставки ems', 0.1315937042236328)
# (151, 'почта россии сроки доставки посылок по россии', 'История почты России', 0.3760659694671631)
# (152, 'почта россии сроки доставки посылок по россии', 'сколько стоит отправить посылку по россии', 0.22536110877990723)
# (153, 'праздники в июне 2018', 'праздники сегодня', 0.44970911741256714)
# (154, 'праздники в июне 2018', 'как отдыхаем на новый год 2019 и выходные дни на январские праздники', 0.22900229692459106)
# (155, 'праздники в июне 2018', 'производственный календарь 2018', 0.05759996175765991)
# (156, 'приквкл', 'приквел звездных войн', 0.0)
# (157, 'приквкл', 'что такое спин-офф', 0.0)
# (158, 'приквкл', '10 лучших приквелов в истории Голливуда', 0.0)
# (159, 'приквкл', 'чем сиквел отличается от приквела', 0.0)
# (160, 'расстояние от вены до амстердама', 'из вены в амстердам на поезде', 0.2972540259361267)
# (161, 'расстояние от вены до амстердама', 'что посмотреть по дороге из вены в амстердам', 0.25075989961624146)
# (162, 'расстояние от вены до амстердама', 'авиабилеты из вены в амстердам', 0.03454458713531494)
# (163, 'роблокс', 'как создать новый аккаунт в роблокс если он у тебя уже есть', 0.026364803314208984)
# (164, 'роблокс', 'завести аккаунт в роблокс', 0.24005568027496338)
# (165, 'роблокс', 'играть в роблокс онлайн бесплатно', 0.3904026746749878)
# (166, 'россия онлайн 1 прямой эфир', 'россия 1 программа на сегодня', 0.3703450560569763)
# (167, 'россия онлайн 1 прямой эфир', 'россия 1 официальный сайт', 0.3908003568649292)
# (168, 'россия онлайн 1 прямой эфир', 'россия 1 официальный сайт прямой эфир с андреем малаховым', 0.41684234142303467)
# (169, 'следствие по телу в хорошем качестве', '10 лучших сериалов весны: Выбор редакции', 0.0)
# (170, 'следствие по телу в хорошем качестве', 'где снималась дана дилэйни', 0.0)
# (171, 'следствие по телу в хорошем качестве', 'следствие по телу сериал актёры', 0.42126864194869995)
# (172, 'следствие по телу в хорошем качестве', 'следствие по телу похожие сериалы', 0.4268198013305664)
# (173, 'съедобные птицы', 'что такое боровая дичь', 0.1392974853515625)
# (174, 'съедобные птицы', 'когда охотиться на лесных птиц', 0.11181670427322388)
# (175, 'съедобные птицы', 'съедобные яйца', 0.27534520626068115)
# (176, 'съедобные птицы', 'калорийность птиц', 0.09762352705001831)
# (177, 'съедобные птицы', 'можно ли есть голубей', 0.1007007360458374)
# (178, 'съедобные птицы', 'краткий определитель птиц', 0.12667042016983032)
# (179, 'тульская чайная меню тула', 'где в туле попить чай из самовара', 0.2311849594116211)
# (180, 'тульская чайная меню тула', 'тульская чайная на карте', 0.46126919984817505)
# (181, 'тульская чайная меню тула', 'тульская чайная отзывы', 0.4643899202346802)
# (182, 'уголок фантазеры', 'оформление школьного уголка в детском саду', 0.16048967838287354)
# (183, 'уголок фантазеры', 'купить оформление для классного уголка', 0.14982616901397705)
# (184, 'уголок фантазеры', 'как оформить классный уголок', 0.22395211458206177)
# (185, 'фасадная клиенкерная', 'Подборка красивых фасадов', 0.1462131142616272)
# (186, 'фасадная клиенкерная', 'сколько стоит работа по укладке клинкерной плитке', 0.0)
# (187, 'фасадная клиенкерная', 'как укладывать фасадную клинкерную плитку', 0.1656113862991333)
# (188, 'фасадная клиенкерная', 'как выбрать клинкерную плитку', 0.11152869462966919)
# (189, 'фасадная клиенкерная', 'как сделать фасад', 0.1901332139968872)
# (190, 'фасадная клиенкерная', 'виды фасадов домов', 0.14636433124542236)
# (191, 'хоумстак', 'лучшие комиксы', 0.0)
# (192, 'хоумстак', 'что такое хоумстак', 0.44529956579208374)
# (193, 'хоумстак', 'эндрю хасси', 0.0)
# (194, 'хоумстак', 'читать комикс хоумстак на русском', 0.3203437328338623)
# (195, 'хоумстак', 'C чего начать знакомство с комиксами', 0.0)
# (196, 'хоумстак', 'хоумстак персонажи', 0.49103081226348877)
# (197, 'хоумстак', 'история возникновения комиксов', 0.0)
# (198, 'цена масла гур', 'жидкость гур для чего нужна', 0.2712932229042053)
# (199, 'цена масла гур', 'замена масла гур цена', 0.39402514696121216)
# (200, 'цена масла гур', 'признаки утечки гур', 0.030400216579437256)
# (201, 'чернобыль 2 сезон', 'где снимали чернобыль 2 сезон', 0.43789541721343994)
# (202, 'чернобыль 2 сезон', 'чернобыль зона отчуждения актеры', 0.4380267858505249)
# (203, 'чернобыль 2 сезон', 'факты о чернобыле', 0.3206595182418823)
# (204, 'чернобыль 2 сезон', 'на каком канале идет чернобыль 2', 0.27579110860824585)
# (205, 'экспоцентр мультитурнире золотой тигр', 'мультитурнир золотой тигр 2018 фото', 0.1462128758430481)
# (206, 'экспоцентр мультитурнире золотой тигр', 'мультитурнир золотой тигр 2018 екатеринбург экспо', 0.16784358024597168)
# (207, 'экспоцентр мультитурнире золотой тигр', 'мультитурнир золотой тигр регламент взвешивания', 0.12851029634475708)
# (208, 'яндекс карты', 'популярные места в городе', 0.0)
# (209, 'яндекс карты', 'пробки в москве', 0.0)
# (210, 'advanced 3d audio processing console', 'advanced 3d audio processing csgo reddit', 0.49468713998794556)
# (211, 'advanced 3d audio processing console', 'csgo sound settings 2018', 0.0)
# (212, 'advanced 3d audio processing console', 'advanced 3d audio processing console commands', 0.4982234239578247)
# (213, 'air datepicker default value', 'jquery datepicker default date', 0.08681058883666992)
# (214, 'air datepicker default value', 'air datepicker примеры', 0.4893953800201416)
# (215, 'air datepicker default value', 'air datepicker не работает', 0.48313969373703003)
# (216, 'focus group', 'focus group что это', 0.48948603868484497)
# (217, 'focus group', 'focus group агентство', 0.4876009225845337)
# (218, 'focus group', 'focus group отзывы сотрудников', 0.4806220531463623)
# (219, 'i know you love me', 'i know you love me justin bieber ', 0.4909740686416626)
# (220, 'i know you love me', 'любовь в музыке', 0.01848822832107544)
# (221, 'i know you love me', 'i know you love me слушать', 0.49233192205429077)
# (222, 'i know you love me', 'i know you love me Lisa Ekdahl', 0.48763811588287354)
# (223, 'i know you love me', 'Лучшие песни о любви', 0.005472004413604736)
# (224, 'i know you love me', 'Истории про песни о любви', 0.0)
# (225, 'roundcube new user', 'Лучшие Программы Для Электронной Почты', 0.0)
# (226, 'tea funny краснодар', 'кафе в краснодаре', 0.0)
# (227, 'tea funny краснодар', 'из чего делают бабл ти', 0.0)
# (228, 'tea funny краснодар', 'ти фанни меню ', 0.15720152854919434)
# (229, 'tea funny краснодар', 'Лучшие рестораны Краснодара', 0.0)
# (230, 'translate', 'где перевести текст целиком', 0.0)
# (231, 'translate', 'словарь английского языка с транскрипциями', 0.0)
# (232, 'translate', 'лучшее приложение для перевода', 0.0)
# (233, 'translate', '6 способов выучить английский быстро', 0.0)
# (234, 'yoobao 10000 mah', 'как выбрать внешний аккумулятор', 0.0)
# (235, 'yoobao 10000 mah', 'лучшие внешние аккумуляторы', 0.0)
# (236, 'yoobao 10000 mah', 'как правильно пользоваться внешним аккумулятором', 0.0)
# (237, 'yoobao 10000 mah', 'необычные павербанки', 0.0)
# (238, 'yoobao 10000 mah', 'yoobao 10000 mah обзор', 0.4961589574813843)
# (239, 'yoobao 10000 mah', 'как выбрать внешний аккумулятор', 0.0)
# (240, 'hh.ru', 'шарики', 0.0)
# (241, 'погода в стерлитамаке на 10 дней', 'скейтборд уходит в сторону', 0.0)
# (242, 'погода в стерлитамаке на 10 дней', 'скейтборд уходит в сторону', 0.0)
# (243, 'пепа свинка смотреть все серии подряд', 'рассольник рецепт', 0.0017323493957519531)
# (244, 'вскоре', 'как сделать плоское стекло', 0.0)
# (245, 'yнаказание за использование воды из теплотрассы', 'как восстановить айфон через itunes', 0.005244433879852295)
# (246, 'как сыграла россия с испанией сегодня', 'аккаунт гугл', 0.0)
# (247, 'спираль логарифмическая', 'сколько варить кукурузу', 0.0)
# (248, 'Яндекс', 'как избавиться от гнид', 0.0)
# (249, 'порно суссана', 'скрытые друзья в вк', 0.0)
# (250, 'утиные истории', 'что делать', 0.0)
# (251, 'что играло на лав радио сегодня плейлист', 'грудинка свиная рецепты приготовления', 0.0)
# (252, 'loft fitness ярославль цены', 'шарики', 0.0)
# (253, 'Spectrasonics Omnisphere 2.5', 'как сделать интернет магазин', 0.0)
# (254, 'курящая кура', 'как перестать смущаться и краснеть', 0.0)
# (255, 'war and magic как часто выходят новые сервера?', 'ядовитые змеи', 0.0)
# (256, 'сверхъестественное 1 сезон', 'как сделать снюс из сигареты', 0.0)
# (257, 'гдз 2 класс окружающий мир рабочая тетрадь 1 часть плешаков новицкая', 'почему мусульмане не едят свинину по корану', 0.0)
# (258, 'три страшных дня из жизни ректора скачать', 'выкройка рюкзака', 0.0)
# (259, 'курица в духовке с картошкой и помидорами', 'можно ли заниматься сексом при месячных', 0.0)
# (260, 'берег пенза ресторан', 'что можно приготовить на костре', 0.0)
# (261, 'при какой погоде гулять с коровой', 'проверить налоги', 0.0)
# (262, 'интервью симоньян петров и баширов', 'как сделать внутримышечный укол', 0.0)
# (263, 'паллетов', 'нанесение тяжких телесных', 0.0)
# (264, 'десантник степочкин 1 2 3 скачать бесплатно через торрент', 'как посадить розу', 0.0)
# (265, 'продам поддонов б у цена томск', 'во что поиграть на пк', 0.0)
# (266, '4 августа выборг', 'макароны приготовление', 0.0)
# (267, 'что произошло в адлере вчера', 'как похудеть при помощи ходьбы', 0.0)
# (268, 'девальвация что это такое', 'как извлекать корни из чисел', 0.0)
# (269, 'польский мультфильм про черта у которого не росли рога', 'как приготовить патиссоны', 0.0)
# (270, 'zakupki 223 eltorg org', 'объединить пдф', 0.0)
# (271, 'ивлеева это', 'как похудеть на 5 кг за месяц', 0.0)
# (272, 'локомотивная 104 ульяновск', 'где заработать денег', 0.0)
# (273, 'чехов баня', 'как быстро похудеть', 0.0)
# (274, 'Опасности в ведении ресторанного бизнеса', 'как научиться свистеть громко с пальцами', 0.0)
# (275, 'xvideo', 'как скрыть друга в вк', 0.0)
# (276, 'заячий остров в санкт-петербурге почему так называется', 'узнать диаметр по длине окружности калькулятор онлайн', 0.0)
# (277, 'marianna tcaciuc', 'как скрыть статус онлайн в вконтакте на айфоне', 0.0)
# (278, 'правгород калуга квартиры', 'грамотная речь как научиться говорить красиво и грамотно упражнения', 0.0)
# (279, 'автовокзал-онлайн.рф иркутск', 'как открыть файлы на андроиде', 0.0)
# (280, 'марафон 8_9 сентября', 'вросший волос что делать', 0.0)
# (281, 'фото после сахарной депиляции', 'как экономить деньги', 0.0)
# (282, 'квартиры в аренду в екатеринбурге от собственников', 'как составить резюме', 0.0)
# (283, 'чиж и филин', 'как без компаса определить где север', 0.0)
# (284, 'apotnoonline', 'как правильно курить', 0.0)
# (285, 'можно ли сварить яйцо в микроволновке', 'скрытые друзья вк', 0.0)
# (286, '12.9ч.2 что за нарушение', 'как избавиться от тараканов', 0.0)
# (287, 'эритромицин для глаз', 'сколько запекать картошку в духовке', 0.0)
# (288, 'найти иголку в одежде что значит', 'как изменить жизнь к лучшему', 0.0)
# (289, 'найти иголку в одежде что значит', 'как стать красивой и ухоженной девушкой в домашних условиях в 17 лет', 0.029597163200378418)
# (290, 'почему возникают задержки месячных', 'есть ли смысл учить немецкий язык', 0.0)
# (291, 'русская эскадра водка пограничная', 'упражнение кегеля', 0.0)
# (292, 'данелия тулешова', 'как полюбить свою работу', 0.0)
# (293, 'Создать сайт с нуля', 'как приготовить окрошку', 0.021112442016601562)
# (294, 'как узнать по ip адресу местоположение', 'как приготовить плов', 0.0)
# (295, 'как делать очень мягкий хлеб', 'как убрать пивной живот у мужчины', 0.19710683822631836)
# (296, 'курс фунта стерлинга к рублю на сегодня', 'как приготовить рис', 0.0)
# (297, 'несокрушимый 2018 посмотреть завтра в москве', 'мозг человека', 0.0)
# (298, 'гдз по русскому языку 8 класс ладыженская', 'что делать при сотрясении', 0.0)
# (299, 'картофельные драники', 'как почистить серебро в домашних условиях', 0.0)
# (300, 'как удалить виндовс', 'задержка месячных', 0.0)
# (301, 'как удалить виндовс', 'как правильно и вкусно готовить макароны', 0.0)
# (302, 'joe anderson', 'сколько держать фольгу чтобы снять гель лак', 0.0)
# (303, 'афиша концертов в дк г жуковскийв октябре2018г', 'из лоскутов', 0.0)
# (304, 'как стать красивой и ухоженной девушкой в домашних условиях', 'как избавиться от икоты', 0.014957189559936523)
# (305, 'я избегаю парней', 'гугл документы', 0.0)
# (306, 'что делать если не любишь человека но тебя к нему тянет', 'какой объем файла можно отправить по почте mail', 0.0)
# (307, 'смешные хохляцкие фамилии', 'колумб открыл америку', 0.0)
# (308, 'во сколько открывается метро перово', 'как варить рис', 0.0)
# (309, 'антибакториальные смазки для анального секса', 'учиюру кабинет ученика войти', 0.0)
# (310, 'ту ту точка ру сапсан тверь санкт питербург', 'как полюбить свою работу', 0.0)
# (311, 'площадь цилиндра онлайн калькулятор', 'вкусное блюдо из цветной капусты быстро', 0.0)
# (312, 'where the apple', 'прыщ на носу как быстро избавиться', 0.0)
# (313, 'дипломная работа', 'как варить гречку', 0.0)
# (314, 'чай с зверобоем польза и вред', 'ручка дверного замка не возвращается', 0.0)
# (315, 'свадьба с ограниченным бюджетом', 'блюдо из цветной капусты', 0.0)
# (316, 'как найти лаунчер майнкрафт на компьютере', 'сколько варить кукурузу', 0.0)
# (317, 'как найти лаунчер майнкрафт на компьютере', 'шум от соседей', 0.0)
# (318, 'как найти лаунчер майнкрафт на компьютере', 'как варить яйца вкрутую', 0.0)
# (319, 'барби', 'как нарисовать мышку', 0.0)
# (320, 'чем полезна брюссельская капуста', 'цветная капуста рецепты', 0.2717718482017517)
# (321, 'чем полезна брюссельская капуста', 'что подарить парню', 0.0)
# (322, 'как подсчитать время нескольких музыкальных файлов', 'как уехать жить в белоруссию на пмж из россии', 0.0)
# (323, 'как избавиться от муравьев на огороде', 'как раскрутить инстаграм', 0.0)
# (324, 'капуста виды капусты фото названия', 'как развести гипс', 0.0)
# (325, 'капуста виды капусты фото названия', 'цветная капуста рецепты', 0.41688990592956543)
# (326, 'брокколи рецепты приготовления', 'создать гугл аккаунт', 0.0)
# (327, 'пионер кинотеатр парк горького', 'как перевести номер на другого оператора', 0.0)
# (328, 'skillbox', 'как увидеть скрытые папки', 0.0)
# (329, 'https://www.ufanet.ru/ m3u8', 'аппендицит', 0.0)
# (330, 'ребёнок в шесть лет не учит стихи', 'как ухаживать за орхидеей', 0.0)
# (331, 'ребёнок в шесть лет не учит стихи', 'как выбрать орхидею', 0.0)
# (332, 'PLAY GAME', 'ноутбук', 0.0)
# (333, 'самсунг галакси а8+ 2018 обзор', 'как осознать свою цель', 0.0)
# (334, 'трм202 для измерения температуры воздуха', 'интроверт кто это', 0.0)
# (335, 'трм202 для измерения температуры воздуха', 'кардио тренировка', 0.0)
# (336, 'ауди сказка на ночь для детей 3-9 лет', 'водяная баня как сделать в домашних условиях', 0.024981260299682617)
# (337, 'варусная деформация стопы', 'как варить кукурузу в початках в кастрюле', 0.0)
# (338, 'реестр экстремистских материалов', 'как сварить плов', 0.0)
# (339, 'фломастеры', 'ноутбук', 0.0)
# (340, 'частота электрического тока', 'как быстро отрастить волосы', 0.0)
# (341, 'тяжело учиться', 'рассчитать имт', 0.0)
# (342, 'пневматический пистолет цена', 'серотонин что это такое', 0.0)
# (343, 'translate google', 'как заработать деньги в интернете', 0.0)
# (344, 'темный инстинкт сериал россия смотреть онлайн бесплатно в качестве hd 720', 'как мастурбировать', 0.0)
# (345, 'peg perego прогулочная коляска', 'очистить компьютер от мусора', 0.0)
# (346, 'addisonlee contacts', 'котлеты из кабачков', 0.0)
# (347, 'контакт карина назмутдинова', 'перекись водорода применение', 0.0)
# (348, 'свинка пеппа 100 серий подряд без остановки 2017 года', 'как правильно водить велосипед', 0.0)
# (349, 'сбербанк онлайн', 'как сделать банановые чипсы', 0.0)
# (350, 'свечи ректальные', 'как вылечить геморрой', 0.0)
# (351, 'ганг банг', 'как повысить кислотность желудка', 0.0)
# (352, 'аочему после секса дрожжат руки', 'как приготовить щи', 0.0)
# (353, 'помощь в разблокировке счета налоговой', 'восстановление системы на компьютере', 0.047701478004455566)
# (354, 'meiho feeder box 1800', 'заложило ухо что делать', 0.0)
# (355, 'pinterest', 'как варить борщ', 0.0)
# (356, 'какие грибы растут в начале июля', 'как признаться в своих чувствах парню', 0.0)
# (357, 'ядовитые пауки', 'что подарить парню на день рождения', 0.0)
# (358, 'клан сопрано', 'ячмень на глазу как лечить', 0.0)
# (359, 'как очистить серебряную цепочку', 'как избавиться от ос', 0.0)
# (360, 'костный мозг', 'как сделать фон в ворде', 0.0)
# (361, 'vk', 'разделить пдф', 0.008963823318481445)
# (362, 'оладьи из кабачков рецепты с фото простые и вкусные', 'признаки беременности', 0.0)
# (363, 'вкусные рецепты', 'как высчитать день овуляции', 0.0)
# (364, 'рецепты из цветной капусты вкусные и простые', 'чем отравить ворону', 0.0)
# (365, 'цветная капуста как заморозить на зиму', 'как не пойти в школу', 0.0)
# (366, 'цветная капуста как заморозить на зиму', 'интроверт кто это', 0.0)
# (367, 'слова заканчивающиеся на лот', 'как создать свой сайт', 0.0)
# (368, 'удары в боксе', 'как назвать альбом', 0.0)
# (369, 'как избавиться от мух', 'удалить аккаунт facebook', 0.0)
# (370, 'как избавиться от мух', 'как просушиться', 0.0030049681663513184)
# (371, 'Шойгу в алабино 2018', 'письмо преподавателю от студента пример', 0.0)
# (372, 'проститутки тула', 'как определить что аппендицит болит', 0.0)
# (373, 'Microsoft Excel', 'сжать файл пдф онлайн', 0.0)
# (374, 'конвертер из jpg в пдф', 'как стать любимчиком учителя', 0.0)
# (375, 'большая игра сериал 2018 скачать торрент', 'как снять гель лак в домашних условиях', 0.0)
# (376, 'гарантия на сайт', 'как правильно настроить зеркала заднего вида в легковом автомобиле', 0.0)
# (377, 'юлиана караулова обноженная', 'разделить пдф', 0.0)
# (378, 'месячные 7 8 9 сентября, как зачать девочку', 'блюда из кабачков', 0.0)
# (379, 'чешется левый глаз к чему это', 'что такое сон', 0.0)
# (380, 'бары и клубы сейчас', 'фокусы', 0.0)
# (381, 'молоко', 'как определить перелом', 0.0)
# (382, 'генератор камаз евро 3 цена', 'как сделать чтобы пошли месячные', 0.0)
# (383, 'учебник по русскому языку 8 класс ладыженская', 'как приготовить щи', 0.0)
# (384, 'Как построить отношения с мальчиком который старше на 7 лет', 'начинка для пирожков', 0.0)
# (385, 'открытки с днём рождения женщине красивые с пожеланиями бесплатно скачать', 'как научить ребёнка читать по слогам в домашних условиях 6 лет', 0.0)
# (386, 'могут ли быть голодные боли в спине и в желудке', 'как сделать квас', 0.0)
# (387, 'пиздоблядск', 'как забыть плохие воспоминания', 0.0)
# (388, 'как испечь лепешки на кефире на сковороде', 'как извиниться перед парнем', 0.0)
# (389, 'какие города бывают на букву я', 'как отключить рекламу на ютубе', 0.0)
# (390, 'как стать фрилансером', 'самоучитель игры на гитаре с нуля', 0.0)
# (391, 'мастурбация это', 'вкусные кабачки что приготовить из молодых кабачков', 0.0)
# (392, 'колобок читать', 'как быстро заснуть', 0.0)
# (393, 'колобок читать', 'как одеться к школе', 0.0)
# (394, 'произношение слова much', 'как зарабатывать в интернете', 0.0)
# (395, 'дверь в лето ленинск кузнецкий', 'плоскостопие', 0.0)
# (396, 'депрессия', 'очень тонкий голос', 0.0)
# (397, 'смешарики дежавю в хорошем качестве', 'объединить пдф', 0.0)
# (398, 'как мотивировать себя', 'аппендицит', 0.0)
# (399, 'гугл', 'что будет если позвонить на номер 666', 0.0)
# (400, 'купить 4 комнатную квартиру в новосибирске', 'как установить мод на майнкрафт', 0.0)
# (401, 'картинки с днем учителя', 'как научиться целоваться', 0.0)
# (402, 'yup перевод', 'как звонить в германию', 0.0)
# (403, 'yup перевод', 'ноут не видит проектор', 0.0)
# (404, 'еженощное пробуждение с', 'что такое метаболизм', 0.0)
# (405, 'гдз', 'как с телефона перенести фотографии на компьютер', 0.0)
# (406, 'крутые бейсболки мужские фото', 'сквирт ощущения', 0.002138972282409668)
# (407, 'как сесть на шпогат', 'секс во время месячных', 0.0)
# (408, 'гимнастика в сыктывкаре', 'как установить мод на майнкрафт', 0.0)
# (409, 'как правильно делать омовение перед намазом', 'вкусные кабачки что приготовить из молодых кабачков', 0.0)
# (410, 'прогноз на матч польша италия', 'блюда из кабачков', 0.0)
# (411, 'александр руденко барнаул', 'фаршированные перцы', 0.0)
# (412, 'к чему снится пауки большие мохнатые живые', 'как написать заявление на увольнение', 0.0)
# (413, 'отдых в дидим', 'число пи', 0.0)
# (414, 'как приготовить шарлотку с яблоками', 'как получить гражданство', 0.0)
# (415, 'как сварить яблочный компот', 'на каком сайте можно посмотреть фильмы в хорошем качестве бесплатно', 0.0)
# (416, 'допустимая норма алкоголя за рулем в промилле', 'гугл документы', 0.0)
# (417, 'горит рот за губами', 'во сколько нужно приходить на исповедь', 0.0)
# (418, 'салаты рецепты с фото простые и вкусные', 'как подкурить сигарету без зажигалки и спичек дома', 0.0)
# (419, 'как выгодно купить как выгодно купить новый автомобиль в салоне в кредит в городе ижевск', 'как сесть на шпагат', 0.0)
# (420, 'как выгодно купить как выгодно купить новый автомобиль в салоне в кредит в городе ижевск', 'как удалить мозоли на ногах в домашних условиях', 0.0)
# (421, 'поргина людмила в молодости', 'как играть в судоку', 0.0)
# (422, 'трагедия в шарлыке', 'цветная капуста как приготовить', 0.0)
# (423, 'трагедия в шарлыке', 'как заблокировать все порно сайты', 0.0)
# (424, 'как правильно троллить', 'гугл документы', 0.0)
# (425, 'жареные огурцы', 'ноутбук', 0.0)
# (426, 'перечисли твоего любимого героя в my little pony', 'как правильно целоваться с парнем в первый раз', 0.01310718059539795)
# (427, 'сериал молодежка лед и пламя смотреть онлайн', 'как запомнить сон', 0.0)
# (428, 'можно ли восстановить переписку в вк с телефона', 'как варить рис', 0.0)
# (429, 'птоз это', 'как брить зону бикини без раздражения', 0.0)
# (430, 'макарьевский монастырь', 'как сжать фильм для записи на флешку без потери качества', 0.0)
# (431, 'когда 3 сезон улицы', 'как бросить пить и курить', 0.0)
# (432, 'сонник-толкование парень который нравится с цветами', 'как варить рис', 0.0)
# (433, 'что делать если у меня болит живот и меня подташнивает в 13 14 лет', 'как ухаживать за орхидеями в домашних условиях в горшке', 0.0)
# (434, 'эротика', 'приготовление шашлыка', 0.0)
# (435, 'советск ленина 45', 'как завязывать галстук', 0.0)
# (436, 'синицина ирина', 'как варить кукурузу', 0.0)
# (437, 'смотреть нтв в прямом эфире бесплатно в хорошем', 'как сделать грудное молоко жирным и питательным', 0.0)
# (438, 'живая сталь смотреть', 'рецепт из кабачков', 0.0)
# (439, 'как удалить все фото со стены в вк', 'как приготовить плов', 0.0)
# (440, 'порно стонет', 'как готовить макароны', 0.0)
# (441, 'федорова оксана порно', 'как ухаживать за орхидеей', 0.0)
# (442, 'разбор игры на гитаре песни behaind blow ice', 'что нужно сдавать чтобы стать психологом', 0.0)
# (443, 'шиншилла лезет шерсть', 'как улучшить настроение', 0.0)
# (444, 'заповедники и национальные парки в астнахани', 'блюда из кабачков', 0.0)
# (445, 'нужно ли хрустеть спиной', 'как раскрутить инстаграм', 0.0)
# (446, 'санаторий поречье бндпрусь', 'что подарить парню на день рождения', 0.0)
# (447, 'налог на прибыль физ лиц', 'как курить кальян', 0.0)
# (448, 'школа 17', 'фаршированные перцы', 0.0)
# (449, 'расписание автобусов большой исток екатеринбург 182', 'что такое метаболизм', 0.0)
# (450, 'моя страница вконтакте', 'серотонин что это такое', 0.0)
# (451, 'сбербанк', 'удалить аккаунт facebook', 0.0)
# (452, 'филдер тойота', 'как варить рис', 0.0)
# (453, 'взаимные аспекты луна плутон в синастрии', 'как варить борщ', 0.0)
# (454, 'майл лру', 'как получить гражданство', 0.0)
# (455, 'измены 2 сезон 1 серия', 'как бросить пить и курить', 0.0)
# (456, 'рамблер новости', 'как приготовить рис', 0.0)
# (457, 'pandao интернет магазин на русском', 'как приготовить окрошку', 0.0)
# (458, 'художественные средства литература', 'как подкурить сигарету без зажигалки и спичек дома', 0.0)
# (459, 'как продлить полис осаго в согазе онлайн', 'как уменьшить размер файла jpg', 0.06664091348648071)
# (460, 'на какой день задержки делать тест', 'сколько запекать картошку в духовке', 0.0)
# (461, 'минелла мартинцова прогноз', 'аккаунт гугл', 0.0)
# (462, 'монстры на каникулах 3 море зовёт мультфильм 2018', 'как сделать бумажный кораблик', 0.0)
# (463, 'среднестатистический рост мужчины в россии', 'есть ли смысл учить немецкий язык', 0.0)
# (464, '+78352641485', 'как правильно и вкусно готовить макароны', 0.0)
# (465, 'ограничитель открывания окна с тросом купить', 'чем отравить ворону', 0.0)
# (466, 'как сравнить уксус с лимонной кислотой в пропорции', 'колумб открыл америку', 0.0)
# (467, 'большой адронный коллайдер', 'заложило ухо что делать', 0.0)
# (468, 'чёрный кофе песня', 'что нарисовать', 0.0)
# (469, 'мультики про камазы для детей от 2 лет до 10 лет', 'как курить сигару', 0.0)
# (470, 'ничем не занимаюсь', 'как удалить сообщения в фейсбук навсегда', 0.0)
# (471, 'авито иваново', 'как правильно водить велосипед', 0.0)
# (472, 'классический соус для греческого салата', 'как курить сигару', 0.07699912786483765)
# (473, 'насадки для мясорубки мулинекс ME 74030', 'как правильно заплести косички', 0.07476705312728882)
# (474, 'последний человек на земле', 'пахнет мочой из интимной зоны женская', 0.0024633407592773438)
# (475, 'как создавали элвина и бурундуков', 'как вылечить геморрой', 0.0)
# (476, 'гдз по английскому языку 5 класс афанасьева михеева баранова учебник 1', 'как избавиться от икоты', 0.0)
# (477, 'встраиваемая микроволновая печь', 'как поймать мышей в домашних условиях', 0.0)
# (478, 'вк', 'секс во время месячных', 0.0)
# (479, 'кинопоиск лучшие сериалы', 'ручка дверного замка не возвращается', 0.0)
# (480, 'супрастин инструкция по применению', 'котлеты из кабачков', 0.0)
# (481, 'маршрут 102 маршрутки спб на карте с изменениями', 'как варить кукурузу в початках в кастрюле', 0.0)
# (482, 'художественное порно фильмы', 'ткемали что это', 0.0)
# (483, 'хабиб и конор прямая трансляция', 'объединить пдф', 0.0)
# (484, 'запрещённое порно', 'как убрать жир на грудных мышцах у мужчин', 0.0)
# (485, 'сайт с нуля пошаговая инструкция для новичков', 'уверенность в себе это', 0.0)
# (486, 'электронный дневник', 'как поставить палатку', 0.0)
# (487, 'с днем рождения', 'сколько варить кукурузу', 0.0)
# (488, 'повышение воспитательного потенциала урока биологии', 'просел диван что делать', 0.0)
# (489, 'как лечить сухой кашель у ребенка', 'как сделать квас', 0.06464093923568726)
# (490, 'график работы мрэо тольятти заставная', 'потерял номер от машины что делать', 0.0)
# (491, 'вирджиния вульф', 'фаршированные перцы', 0.004948258399963379)
# (492, 'новоминская авангард аутсоринговая компания', 'как убрать пивной живот у мужчины', 0.0)
# (493, 'русское лото', 'как получить галочку в инстаграме', 0.0)
# (494, 'ютуб', 'как отучить кота сать где попало', 0.0)
# (495, 'почему армянки красивые', 'отучить котенка писать на кровать', 0.0)
# (496, 'борщевик сосновского история создания', 'как хранить деньги в кошельке', 0.0)
# (497, 'солнечный берег чувашия новый год', 'жирная кожа лица что делать', 0.0)
# (498, 'вязаная шапка из толстых ниток', 'как ломается голос у девочек', 0.0)
# (499, 'погода в иркутске', 'как выбрать обои', 0.0)

# %%
len(res_not_zero)
# Out:
# 171

# %%
for i in range(147, len(res_all)):
  if res_all[i][3] <= 0.1:
    ans.append((res_all[i][0], res_all[i][1], res_all[i][2], 0))
  elif res_all[i][3] >= 0.25:
    ans.append((res_all[i][0], res_all[i][1], res_all[i][2], 1))
  else:
    print(res_all[i][1], res_all[i][2], res_all[i][3])
    t = int(input())
    ans.append((res_all[i][0], res_all[i][1], res_all[i][2], t))
# Out:
# не убирается подчеркивание ссылок как в css убрать подчеркивание ссылки 0.12149858474731445
# 0
# почта россии сроки доставки посылок по россии скорость доставки ems 0.1315937042236328
# 0
# почта россии сроки доставки посылок по россии сколько стоит отправить посылку по россии 0.22536110877990723
# 0
# праздники в июне 2018 как отдыхаем на новый год 2019 и выходные дни на январские праздники 0.22900229692459106
# 0
# роблокс завести аккаунт в роблокс 0.24005568027496338
# 1
# съедобные птицы что такое боровая дичь 0.1392974853515625
# 0
# съедобные птицы когда охотиться на лесных птиц 0.11181670427322388
# 0
# съедобные птицы можно ли есть голубей 0.1007007360458374
# 0
# съедобные птицы краткий определитель птиц 0.12667042016983032
# 0
# тульская чайная меню тула где в туле попить чай из самовара 0.2311849594116211
# 1
# уголок фантазеры оформление школьного уголка в детском саду 0.16048967838287354
# 0
# уголок фантазеры купить оформление для классного уголка 0.14982616901397705
# 0
# уголок фантазеры как оформить классный уголок 0.22395211458206177
# 0
# фасадная клиенкерная Подборка красивых фасадов 0.1462131142616272
# 0
# фасадная клиенкерная как укладывать фасадную клинкерную плитку 0.1656113862991333
# 0
# фасадная клиенкерная как выбрать клинкерную плитку 0.11152869462966919
# 0
# фасадная клиенкерная как сделать фасад 0.1901332139968872
# 0
# фасадная клиенкерная виды фасадов домов 0.14636433124542236
# 0
# экспоцентр мультитурнире золотой тигр мультитурнир золотой тигр 2018 фото 0.1462128758430481
# 1
# экспоцентр мультитурнире золотой тигр мультитурнир золотой тигр 2018 екатеринбург экспо 0.16784358024597168
# 1
# экспоцентр мультитурнире золотой тигр мультитурнир золотой тигр регламент взвешивания 0.12851029634475708
# 0
# tea funny краснодар ти фанни меню  0.15720152854919434
# 0
# как делать очень мягкий хлеб как убрать пивной живот у мужчины 0.19710683822631836
# 0

# %%
ans_df = pd.DataFrame(answers, columns =['', 'query1', 'query2', 'label'])
ans_df.drop(columns=[""], inplace=True)
ans_df
# Out:
#                                           query1  ... label
# 0                             как царапать глаза  ...     0
# 1    основные методы реабилитации пороках сердца  ...     0
# 2               кетонал инструкция по применению  ...     0
# 3                  лобода песня суперзвезда клип  ...     0
# 4                   цинктерал стоимость в аптеке  ...     0
# ..                                           ...  ...   ...
# 495                      почему армянки красивые  ...     0
# 496        борщевик сосновского история создания  ...     0
# 497            солнечный берег чувашия новый год  ...     0
# 498               вязаная шапка из толстых ниток  ...     0
# 499                            погода в иркутске  ...     0
#
# [500 rows x 3 columns]

# %%
ans_df.to_csv(path+'test_dataset_labeled.csv')
ddd = pd.read_csv(path+'test_dataset_labeled.csv')
ddd
# Out:
#      Unnamed: 0  ... label
# 0             0  ...     0
# 1             1  ...     0
# 2             2  ...     0
# 3             3  ...     0
# 4             4  ...     0
# ..          ...  ...   ...
# 495         495  ...     0
# 496         496  ...     0
# 497         497  ...     0
# 498         498  ...     0
# 499         499  ...     0
#
# [500 rows x 4 columns]
